# %%
#ESERCITAZIONE W11D5 - Verrecchia Isabella

# %%
#ESERCIZIO 1: PUB
import pandas as pd

pub = pd.read_csv("Mappa-dei-pub-circoli-locali-in-Italia.csv", encoding="latin1", sep=";")
pub
# Out:
#             Comune                       Provincia   Regione             Nome  \
# 0            ALTRO                           ALTRO     ALTRO              NaN
# 1            ALTRO                           ALTRO     ALTRO      Lenny's Pub
# 2            ALTRO                           ALTRO     ALTRO  Murrayfield Pub
# 3            ALTRO                           ALTRO     ALTRO           Snop?e
# 4     ALA DI STURA  CITTA' METROPOLITANA DI TORINO  Piemonte              NaN
# ...            ...                             ...       ...              ...
# 2630      BARLETTA           BARLETTA-ANDRIA-TRANI    Puglia      Santa Croce
# 2631     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia      Auld Dublin
# 2632     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia            Ferus
# 2633         TRANI           BARLETTA-ANDRIA-TRANI    Puglia          Re Artù
# 2634         TRANI           BARLETTA-ANDRIA-TRANI    Puglia     Well's Fargo
#
# ...

# %%
#Esaminiamo il dataset:
#quanti dati ci sono in totale?
pub.shape
# Out:
# (2635, 9)

# %%
#quali sono i metadati?
pub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2635 entries, 0 to 2634
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Comune                           2635 non-null   object
#  1   Provincia                        2635 non-null   object
#  2   Regione                          2635 non-null   object
#  3   Nome                             2337 non-null   object
#  4   Anno inserimento                 2635 non-null   int64
#  5   Data e ora inserimento           2635 non-null   object
#  6   Identificatore in OpenStreetMap  2635 non-null   int64
#  7   Longitudine                      2635 non-null   float64
#  8   Latitudine                       2635 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 185.4+ KB

# %%
#stampiamo il primo elemento
pub.head(1)
# Out:
#   Comune Provincia Regione Nome  Anno inserimento Data e ora inserimento  \
# 0  ALTRO     ALTRO   ALTRO  NaN              2011   2011-06-25T23:17:43Z
#
#    Identificatore in OpenStreetMap  Longitudine  Latitudine
# 0                       1339088150    13.733257    45.57583

# %%
#stampiamo l'ultimo elemento
pub.tail(1)
# Out:
#      Comune              Provincia Regione          Nome  Anno inserimento  \
# 2634  TRANI  BARLETTA-ANDRIA-TRANI  Puglia  Well's Fargo              2009
#
#      Data e ora inserimento  Identificatore in OpenStreetMap  Longitudine  \
# 2634   2009-08-10T12:44:03Z                        387223648    16.436765
#
#       Latitudine
# 2634   41.267264

# %%
#riusciamo a stampare un elemento a caso?
pub.sample(1)
# Out:
#      Comune                       Provincia    Regione      Nome  \
# 551  MILANO  CITTA' METROPOLITANA DI MILANO  Lombardia  Paperoga
#
#      Anno inserimento Data e ora inserimento  Identificatore in OpenStreetMap  \
# 551              2013   2013-09-17T06:24:26Z                       2461220919
#
#      Longitudine  Latitudine
# 551     9.230016   45.464865

# %%
#quali sono gli anni di inserimento presenti?
pub["Anno inserimento"].unique()
# Out:
# array([2011, 2015, 2010, 2012, 2014, 2016, 2013, 2008, 2009, 2007],
#       dtype=int64)

# %%
#quante attività ci sono nel quadrato di longitudine 9-10 e latitudine 45-46?
filtro_long = (pub["Longitudine"] >=9) & (pub["Longitudine"] <=10)
filtro_lat = (pub["Latitudine"] >=45) & (pub["Latitudine"] <=46)
filtro = filtro_long &  filtro_lat
pub.loc[filtro,["Nome","Longitudine", "Latitudine"]]
# Out:
#                  Nome  Longitudine  Latitudine
# 2     Murrayfield Pub     9.029585   45.831340
# 342               NaN     9.014469   45.585286
# 343        Buenavista     9.021546   45.608240
# 346               NaN     9.031357   45.629008
# 347         Bray Hill     9.030316   45.628685
# ...               ...          ...         ...
# 2607     Pane e trita     9.216413   45.650058
# 2608    The Quiet Man     9.210487   45.648891
# 2609  Bambu Pizza Pub     9.272623   45.614027
# 2610              NaN     9.227324   45.681202
# 2611  St. James' Gate     9.117388   45.677211
#
# [306 rows x 3 columns]

# %%
#quante attività ci sono nella provincia di Vicenza?
filtro = pub["Provincia"] == "VICENZA"
pub.loc[filtro]
# Out:
#                   Comune Provincia Regione                     Nome  \
# 969               ASIAGO   VICENZA  Veneto                 Ghel Pab
# 970               ASIAGO   VICENZA  Veneto           Maddarello 2.0
# 971               ASIAGO   VICENZA  Veneto           Vecchio Mulino
# 972   BASSANO DEL GRAPPA   VICENZA  Veneto                Al Porton
# 973   BASSANO DEL GRAPPA   VICENZA  Veneto            Bar San Marco
# ...                  ...       ...     ...                      ...
# 1037             VICENZA   VICENZA  Veneto              Bar Carioca
# 1038             VICENZA   VICENZA  Veneto                Irish pub
# 1039             VICENZA   VICENZA  Veneto          Miles Davis Pub
# 1040             VICENZA   VICENZA  Veneto          Night Club Boys
# 1041             VICENZA   VICENZA  Veneto  Sir William Wallace Pub
#
#       Anno inserimento Data e ora inserimento  \
# 969               2015   2015-08-10T16:56:06Z
# 970               2015   2015-08-11T18:37:19Z
# ...

# %%
#quante enoteche ci sono, e come si chiamano?
filtro = pub["Nome"].str.contains("enoteca|vino|calice|bottiglia", case=False, regex=True)
filtro = filtro.fillna(False)  # in questo modo escludiamo i casi  in cui i nomi siano nulli altrimenti non esce il risultato!
pub.loc[filtro,"Nome"].count()
# Out:
# C:\Users\Isabella\AppData\Local\Temp\ipykernel_4532\117797655.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   filtro = filtro.fillna(False)  # in questo modo escludiamo i casi  in cui i nomi siano nulli altrimenti non esce il risultato!
# 10

# %%
#quante attività ci sono in Lazio e Abruzzo assieme?
filtro_laz = pub["Regione"] == "Lazio"
filtro_abr = pub["Regione"] == "Abruzzo"
filtro = filtro_laz | filtro_abr
pub.loc[filtro,"Regione"].count()
# Out:
# 337

# %%
#ESERCIZIO 2: ASSICURAZIONI 
#Il dataset insurance.csv contiene dati rispetto a caratteristiche e abitudini delle persone, e della zona in cui vivono, 
#rispetto ai costi individuali per le cure mediche come premio per le assicurazioni sulla salute.

ass = pd.read_csv("datasets/beginner_datasets/insurance.csv")

#Visualizziamone le dimensioni, un'anteprima, e osserviamo i nomi di colonna;
ass.shape
ass.columns
ass

#Quali sono le medie di charges rispetto a region? Ci sono differenze significative?
#uso il group by        (charges=spese sanitarie)
ass.groupby("region")["charges"].mean()  #no, rispetto alle regioni, non ci sono differenze significative

#E rispetto a smoker? E a sex?
ass.groupby("smoker")["charges"].mean() #rispetto a smoker si nota una differenza notevole tra fumatori e non (4 volte di più per i fumatori)
ass.groupby("sex")["charges"].mean()  #rispett al sesso non ci sono differenze significative

#Quali sono i descrittori statistici di bmi? Quali sono minimo, media e massimo di charges rispetto ai diversi quartili dei valori di bmi?
ass["bmi"].describe()
print(ass.groupby("bmi")["charges"].agg(["min","max","mean"]).quantile(0.25))
print(ass.groupby("bmi")["charges"].agg(["min","max","mean"]).quantile(0.50))
print(ass.groupby("bmi")["charges"].agg(["min","max","mean"]).quantile(0.75))
#altro modo (con describe)
ass.groupby("bmi")["charges"].describe()
# Out:
# min     2670.472700
# max     8602.074500
# mean    6914.551588
# Name: 0.25, dtype: float64
# min      5419.86480
# max     14004.17790
# mean    11088.63995
# Name: 0.5, dtype: float64
# min     10582.952325
# max     27841.865720
# mean    16607.582215
# Name: 0.75, dtype: float64
#         count          mean          std          min          25%  \
# bmi
# 15.960    1.0   1694.796400          NaN   1694.79640   1694.79640
# 16.815    2.0   4904.000350  2455.844784   3167.45585   4035.72810
# 17.195    1.0  14455.644050          NaN  14455.64405  14455.64405
# 17.290    3.0   7813.353433  4619.986089   3732.62510   5305.30260
# 17.385    1.0   2775.192150          NaN   2775.19215   2775.19215
# ...       ...           ...          ...          ...          ...
# 48.070    1.0   9432.925300          NaN   9432.92530   9432.92530
# 49.060    1.0  11381.325400          NaN  11381.32540  11381.32540
# 50.380    1.0   2438.055200          NaN   2438.05520   2438.05520
# ...

# %%
#ESERCIZIO 3: IRIS
#Carichiamo in un DataFrame il dataset iris.csv dei beginner_datasets 
# !pip install numpy
import numpy

iris = pd.read_csv("datasets/beginner_datasets/iris.csv")
iris
# Out:
# ...
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#Calcoliamo:
#La media della lunghezza dei petali di tutto il dataset
iris["petal_length"].mean()
# Out:
# 3.758666666666666

# %%
#La media della lunghezza dei petali per ogni specie di Iris, utilizzando il metodo .groupby()
iris.groupby("species")["petal_length"].mean()
# Out:
# species
# Iris-setosa        1.464
# Iris-versicolor    4.260
# Iris-virginica     5.552
# Name: petal_length, dtype: float64

# %%
#Media, minimo e massimo della larghezza dei sepali per ogni specie, utilizzando .groupby() e .agg()
iris.groupby("species")["sepal_width"].agg(["mean","min","max"])
# Out:
#                   mean  min  max
# species
# Iris-setosa      3.418  2.3  4.4
# Iris-versicolor  2.770  2.0  3.4
# Iris-virginica   2.974  2.2  3.8

# %%
#ESERCIZIO 4: VINI
#Nei beginner_datasets, il dataset wine.csv contiene delle analisi organolettiche su diverse qualità di vini:
vini = pd.read_csv("datasets/beginner_datasets/wine.csv")
vini
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#Qual è la media di concentrazione alcolica per ogni qualità? Ci sono differenze? E rispetto alla media totale?
print(vini["alcohol"].mean())
vini.groupby("quality")["alcohol"].mean()    
# Non ci sono grandi differenze, tranne la qualità 5 e la qualità 9, che si discostano anche dalla media totale
# Out:
# 10.491800831149453
# quality
# 3    10.215000
# 4    10.180093
# 5     9.837783
# 6    10.587553
# 7    11.386006
# 8    11.678756
# 9    12.180000
# Name: alcohol, dtype: float64

# %%
#C'è differenza nella concentrazione alcolica per vini bianchi e vini rossi?
vini.groupby("type")["alcohol"].mean()    
#non c'è differenza di concentrazione alconi, tra vini rossi e bianchi
# Out:
# type
# red      10.422983
# white    10.514267
# Name: alcohol, dtype: float64

# %%
#Rifacendo le analisi dei due punti precedenti ma per il pH, cambia qualcosa?
vini.groupby("quality")["pH"].mean()
# Out:
# quality
# 3    3.257667
# 4    3.231620
# 5    3.212189
# 6    3.217726
# 7    3.228072
# 8    3.223212
# 9    3.308000
# Name: pH, dtype: float64

# %%
vini.groupby("type")["pH"].mean()
# Out:
# type
# red      3.311113
# white    3.188267
# Name: pH, dtype: float64

# %%
#Per la concentrazione di ph la differenza è irrisoria, sia per qualità che per tipo.

# %%
#E per i solfati?
print(vini.groupby("quality")["sulphates"].mean())
print(vini.groupby("type")["sulphates"].mean())   #si osserva una differenza tra bianchi e rossi nella concentrazione di solfati
# Out:
# quality
# 3    0.506333
# 4    0.505648
# 5    0.526403
# 6    0.532549
# 7    0.547025
# 8    0.512487
# 9    0.466000
# Name: sulphates, dtype: float64
# type
# red      0.658149
# white    0.489847
# Name: sulphates, dtype: float64

# %%
#ESERCIZIO 5: BOSTON
#Nei beginner_datasets, il file boston.csv contiene il Boston Housing Dataset, che deriva dalle informazioni raccolte dal Census Service
#degli Stati Uniti sulle abitazioni nell'area di Boston

boston = pd.read_csv("datasets/beginner_datasets/boston.csv")
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
#La media del prezzo delle case cambia a seconda della distanza dal fiume Charles?
boston.groupby("chas")["medv"].mean()  
# sì! il prezzo medio delle case è più altro in prossimità del fiume ( valore 1)
# Out:
# chas
# 0    22.093843
# 1    28.440000
# Name: medv, dtype: float64

# %%
#Si nota una correlazione tra il tasso di criminalità e il valore delle abitazioni?
#Come si può spiegare il risultato?
boston["crim"].corr(boston["medv"])  
#c'è una correlazione negavita (molto piccola). vuol dire che al crescere della criminalità il valore delle case diminuisce
# Out:
# -0.3883046085868114

# %%
# Qual è la media del numero di stanze rispetto al rapporto alunni-insegnanti?
#E del valore delle case? Appare esserci una qualche correlazione? Come si può spiegare il risultato?

boston.groupby("ptratio")["rm"].mean()
#al crescere del n° medio di stanze diminuisce leggermente il rapporto alunni-insegnanti.
print (boston["rm"].corr(boston["ptratio"]))  #si nota anche dalla correlazione
# Out:
# -0.3555014945590854

# %%
#Vediamo la media del valore delle case rispetto al rapporto alunni-insegnanti:
boston.groupby("ptratio")["medv"].mean()
# Out:
# ptratio
# 12.6    32.733333
# 13.0    38.025000
# 13.6    50.000000
# 14.4    50.000000
# 14.7    25.717647
# 14.8    25.433333
# 14.9    40.475000
# 15.1    31.600000
# 15.2    26.276923
# 15.3    26.066667
# 15.5    32.700000
# 15.6    30.100000
# 15.9    30.250000
# 16.0    24.320000
# 16.1    24.880000
# 16.4    23.216667
# 16.6    23.856250
# 16.8    22.150000
# 16.9    19.640000
# 17.0    30.600000
# 17.3    24.700000
# 17.4    33.544444
# 17.6    30.700000
# 17.8    26.956522
# 17.9    22.363636
# 18.0    33.100000
# 18.2    22.150000
# 18.3    27.100000
# 18.4    23.131250
# 18.5    23.800000
# 18.6    24.335294
# 18.7    25.122222
# 18.8    17.350000
# 18.9    20.100000
# 19.0    24.900000
# 19.1    22.894118
# 19.2    22.805263
# 19.6    22.575000
# 19.7    21.787500
# 20.1    12.800000
# 20.2    16.611429
# 20.9    21.118182
# 21.0    17.351852
# 21.1    18.900000
# 21.2    17.093333
# 22.0    19.400000
# Name: medv, dtype: float64

# %%
#Rispetto all'accessibilità alle autostrade, cambia qualcosa la media delle età delle abitazioni? 
#E del numero di stanze? E delle tasse?

boston.groupby("rad")["age"].mean()
# Out:
# rad
# 1     45.025000
# 2     64.770833
# 3     49.310526
# 4     60.841818
# 5     69.223478
# 6     60.142308
# 7     40.141176
# 8     67.350000
# 24    89.805303
# Name: age, dtype: float64

# %%
boston.groupby("rad")["rm"].mean()
# Out:
# rad
# 1     6.555850
# 2     6.649958
# 3     6.473026
# 4     6.133118
# 5     6.393157
# 6     6.104731
# 7     6.647765
# 8     6.950792
# 24    6.022152
# Name: rm, dtype: float64

# %%
boston.groupby("rad")["tax"].mean()
# Out:
# rad
# 1     291.450000
# 2     260.666667
# 3     246.078947
# 4     335.981818
# 5     331.843478
# 6     372.884615
# 7     304.411765
# 8     301.250000
# 24    666.000000
# Name: tax, dtype: float64

# %%
#ESERCIZIO 6: DIPENDENTI
#Abbiamo un DataFrame di dipendenti:

employees_df = pd.DataFrame({
'employee_id': [101, 102, 103, 104, 105],
'name': ['Alice', 'Bob', 'Charlie', 'David', 'Emma'],
'department_id': [1, 2, 1, 2, 3]
})

# E un DataFrame di dipartimenti:
departments_df = pd.DataFrame({
'department_id': [1, 2, 3],
'department_name': ['HR', 'IT', 'Finance'],
'location': ['New York', 'San Francisco', 'Chicago']
})

# %%
#Unire questi DataFrame in base alla colonna comune department_id, in modo da avere nel risultato informazioni sia sui dipendenti 
#che sui dipartimenti, usando la funzione .merge()

empl_depar = pd.merge(employees_df,departments_df, on = "department_id", how = "inner")
empl_depar
# Out:
#    employee_id     name  department_id department_name       location
# 0          101    Alice              1              HR       New York
# 1          102      Bob              2              IT  San Francisco
# 2          103  Charlie              1              HR       New York
# 3          104    David              2              IT  San Francisco
# 4          105     Emma              3         Finance        Chicago

# %%
#Per ogni DataFrame, trasformare la colonna department_id nell'indice, facendo in modo che la modifica sia permanente; 
#poi unire i due dataset mediante il metodo .join()

employees_df = employees_df.set_index('department_id')
departments_df = departments_df.set_index('department_id')

employees_df.join(departments_df, how = "inner")      #ci sono differenze perchè department_id si ripete
# Out:
#                employee_id     name department_name       location
# department_id
# 1                      101    Alice              HR       New York
# 2                      102      Bob              IT  San Francisco
# 1                      103  Charlie              HR       New York
# 2                      104    David              IT  San Francisco
# 3                      105     Emma         Finance        Chicago

# %%
#ESERCIZIO 7: AdventureWorksDW
#importiamo le tabelle dimemployee e dimemployeesalesterritory come DataFrame

import os
import dotenv
import sqlalchemy
import pandas as pd

dotenv.load_dotenv(dotenv_path="cred.env", override=True)

username = os.getenv("username")
password = os.getenv("password")
host = os.getenv("host")
dbname = os.getenv("dbname")

connection_string = f"mysql+pymysql://{username}:{password}@{host}/{dbname}"
print(connection_string)

db_engine = sqlalchemy.create_engine(connection_string)
# Out:
# mysql+pymysql://studente_dapt:Ep1c0d3!!D4t4**4n4lys1s@epicode-data-pt-mysql.cvetyjye2qbl.eu-central-1.rds.amazonaws.com/AdventureWorksDW

# %%
query = "SELECT * FROM dimemployee"
dimemployee  = pd.read_sql(query, db_engine)
dimemployee
# Out:
#      EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 0              1               18.0                        14417807
# 1              2                7.0                       253022876
# 2              3               14.0                       509647174
# 3              4                3.0                       112457891
# 4              5                3.0                       112457891
# ..           ...                ...                             ...
# 291          292              290.0                       134219713
# 292          293              272.0                        90836195
# 293          294              277.0                       481044938
# 294          295              290.0                       954276278
# 295          296              294.0                       758596752
#
#      ParentEmployeeNationalIDAlternateKey FirstName           LastName  \
# 0                             446466105.0       Guy            Gilbert
# ...

# %%
query = "SELECT * FROM dimemployeesalesterritory"
dimemployeesalesterritory  = pd.read_sql(query, db_engine)
dimemployeesalesterritory
# Out:
#     EmployeeKey  SalesTerritoryKey
# 0           272                  1
# 1           277                  1
# 2           286                  1
# 3           289                  1
# 4           293                  1
# 5           272                  2
# 6           277                  2
# 7           281                  2
# 8           272                  3
# 9           277                  3
# 10          281                  3
# 11          282                  3
# 12          283                  3
# 13          272                  4
# 14          277                  4
# 15          282                  4
# 16          286                  4
# 17          287                  4
# 18          272                  5
# 19          277                  5
# 20          281                  5
# 21          285                  5
# 22          272                  6
# 23          277                  6
# 24          284                  6
# 25          288                  6
# ...

# %%
#Effettuiamo un join tra i due DataFrame usando le colonne EmployeeKey

empl_salter = pd.merge(dimemployee, dimemployeesalesterritory, on = "EmployeeKey", how = "inner")
empl_salter
# Out:
#     EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 0           272              277.0                       502097814
# 1           272              277.0                       502097814
# 2           272              277.0                       502097814
# 3           272              277.0                       502097814
# 4           272              277.0                       502097814
# 5           272              277.0                       502097814
# 6           277              277.0                       112432117
# 7           277              277.0                       112432117
# 8           277              277.0                       112432117
# 9           277              277.0                       112432117
# 10          277              277.0                       112432117
# 11          277              277.0                       112432117
# 12          277              277.0                       112432117
# ...

# %%
#Controlliamo la dimensione del DataFrame risultante: è quella attesa? 
#Sì è la dimensione attesa, perchè il primo ha 28 colonne, il secondo 2 e quello finale 29 (una in meno perchè ne hanno una in comune)
#Anche per le righe, facendo una inner join prende solo quelle in comune (perciò il numero minore)

# %%
#Importiamo ora la tabella dimsalesterritory ed effettuiamo un join tra questa e il DataFrame risultante della join precedente, 
#usando le colonne SalesTerritoryKey

query = "SELECT * FROM dimsalesterritory"
dimsalesterritory  = pd.read_sql(query, db_engine)
dimsalesterritory
# Out:
#     SalesTerritoryKey  SalesTerritoryAlternateKey SalesTerritoryRegion  \
# 0                   1                           1            Northwest
# 1                   2                           2            Northeast
# 2                   3                           3              Central
# 3                   4                           4            Southwest
# 4                   5                           5            Southeast
# 5                   6                           6               Canada
# 6                   7                           7               France
# 7                   8                           8              Germany
# 8                   9                           9            Australia
# 9                  10                          10       United Kingdom
# 10                 11                           0         Corporate HQ
#
#    SalesTerritoryCountry SalesTerritoryGroup  \
# 0          United States       North America
# ...

# %%
#nuovo merge
empl_salter_dims= pd.merge(empl_salter, dimsalesterritory , on = "SalesTerritoryKey", how = "inner")
empl_salter_dims.columns
# Out:
# Index(['EmployeeKey', 'ParentEmployeeKey', 'EmployeeNationalIDAlternateKey',
#        'ParentEmployeeNationalIDAlternateKey', 'FirstName', 'LastName',
#        'MiddleName', 'NameStyle', 'Title', 'HireDate', 'BirthDate', 'LoginID',
#        'EmailAddress', 'Phone', 'MaritalStatus', 'EmergencyContactName',
#        'EmergencyContactPhone', 'SalariedFlag', 'Gender', 'PayFrequency',
#        'BaseRate', 'VacationHours', 'SickLeaveHours', 'CurrentFlag',
#        'SalesPersonFlag', 'DepartmentName', 'EmployeePhoto', 'Position',
#        'SalesTerritoryKey', 'SalesTerritoryAlternateKey',
#        'SalesTerritoryRegion', 'SalesTerritoryCountry', 'SalesTerritoryGroup',
#        'SalesTerritoryImage'],
#       dtype='object')

# %%
#Su questo DataFrame contare quanti dipendenti ci sono per ogni paese (country) e per ogni regione (region)

empl_salter_dims.groupby("SalesTerritoryCountry")["FirstName"].count()
# Out:
# SalesTerritoryCountry
# Australia          3
# Canada             4
# France             4
# Germany            3
# United Kingdom     3
# United States     22
# Name: FirstName, dtype: int64

# %%
empl_salter_dims.groupby("SalesTerritoryRegion")["FirstName"].count()
# Out:
# SalesTerritoryRegion
# Australia         3
# Canada            4
# Central           5
# France            4
# Germany           3
# Northeast         3
# Northwest         5
# Southeast         4
# Southwest         5
# United Kingdom    3
# Name: FirstName, dtype: int64

# %%
#Valutiamo la media del BaseRate per ogni paese: ci sono differenze?
empl_salter_dims.groupby("SalesTerritoryCountry")["BaseRate"].mean()
#dai risultati osserviamo che orientativamente sono simili, tranne per gli Stati Uniti che hanno il valore più basso.
# Out:
# SalesTerritoryCountry
# Australia         47.764433
# Canada            41.592550
# France            41.592550
# Germany           47.764433
# United Kingdom    47.764433
# United States     39.909309
# Name: BaseRate, dtype: float64
